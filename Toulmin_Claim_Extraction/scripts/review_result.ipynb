# %%
import pandas as pd
from pathlib import Path
import json
import ast

# %%
path = Path(r"../important_results/sample_500_meta_gpt_direct_results.csv")
df = pd.read_csv(path)

# %%
len(df)
# Out:
# 500

# %%
n = 10

ad_texts = df['ad_text'][:n]
gpt_results = df['gpt_toulmin_json'][:n]
for ad_text, result in zip(ad_texts, gpt_results):
    print(f"ad_text: \n {ad_text}")
    print(f"gpt_result: \n {result}")
# Out:
# ad_text:
#  🛑🚨🛑🚨Protecting the Endangerment Finding = Protecting Children's Health! Moms across the country share what rolling back this foundational protection for regulating climate emissions means to them. Listen in and then tell EPA to do its job and keep cutting climate pollution!
# gpt_result:
#  {"claim": "Protecting the Endangerment Finding protects children's health.", "ground": "Not present", "warrant": "Not present"}
# ad_text:
#  Stop Kamala's Radical Plan for America Before It's Too Late
#
# ...

# %%
print(df['gpt_toulmin_json'][0])
# Out:
# {"claim": "Protecting the Endangerment Finding protects children's health.", "ground": "Not present", "warrant": "Not present"}

# %%
path = Path(r"../important_results/sample_500_meta_gpt_results.csv")
df2 = pd.read_csv(path)

# %%
print(df2['gpt_toulmin_json'][0])
# Out:
# {"claim": "Protecting the Endangerment Finding protects children's health.", "ground": "Moms across the country share what rolling back this foundational protection for regulating climate emissions means to them.", "warrant": "Not present"}

# %%
ad_texts = df2['ad_text'][:n]
gpt_results = df2['gpt_toulmin_json'][:n]
for ad_text, result in zip(ad_texts, gpt_results):
    print(f"ad_text: \n {ad_text}")
    print(f"gpt_result: \n {result}")
# Out:
# ad_text:
#  🛑🚨🛑🚨Protecting the Endangerment Finding = Protecting Children's Health! Moms across the country share what rolling back this foundational protection for regulating climate emissions means to them. Listen in and then tell EPA to do its job and keep cutting climate pollution!
# gpt_result:
#  {"claim": "Protecting the Endangerment Finding protects children's health.", "ground": "Moms across the country share what rolling back this foundational protection for regulating climate emissions means to them.", "warrant": "Not present"}
# ad_text:
#  Stop Kamala's Radical Plan for America Before It's Too Late
#
# ...

# %%
inputs = df['input']
input_prompts = df['input_prompt']
responses = df['response']

# %%
n = 10
for i in range(n):
    input = inputs[i]
    input_prompt = input_prompts[i]
    response = responses[i]
    print(f"Input: {input}")
    print(f"Input prompt: {input_prompt}\n\n")
    print(f"Output: {response}\n\n")
# Out:
# Input: Be bold! Be a peacemaker and talk climate!
#
# Sign up today to receive tips and resources on how to have these conversations. There will also be a virtual workshop on practicing these skills that you will not want to miss!,Be bold! Be a peacemaker and talk climate!
#
# Sign up today to receive tips and resources on how to have these conversations. There will also be a virtual workshop on practicing these skills that you will not want to miss!
# Input prompt: "Be bold! Be a peacemaker and talk climate!
#
# Sign up today to receive tips and resources on how to have these conversations. There will also be a virtual workshop on practicing these skills that you will not want to miss!,Be bold! Be a peacemaker and talk climate!
#
# Sign up today to receive tips and resources on how to have these conversations. There will also be a virtual workshop on practicing these skills that you will not want to miss!"
#
#  Please define above Toulmin components explicitly:
# ...

# %%
path = Path(r"../results/sample_500_meta_result_format_result_support_result.csv")
df = pd.read_csv(path)
inputs = df['input']
input_prompts = df['input_prompt']
responses = df['response']
metadata = df['metadata']

# %%
keys = df['llm_theme'].unique()

# %%
print(keys)
# Out:
# ['**"Pro-solar advocacy"**' '**"Solar energy advocacy"**'
#  '**"Ocean conservation call"**' '**"Local civic engagement"**'
#  '**"Solar emergency power"**' '**"Public climate input"**'
#  '**"Climate crisis advocacy"**' '**"Anti-Harris energy attack"**'
#  '**"Big Oil accountability"**' '**"Clean energy advocacy"**'
#  '**"Pro-climate candidate"**' '**"Pro-infrastructure investment"**'
#  '**"Pro-clean energy jobs"**' '**"Pro-recycling advocacy"**'
#  '**"Pro-nuclear advocacy"**' '**"Climate education advocacy"**'
#  '**"Methane regulation push"**' '**"Local food advocacy"**'
#  '**"Pro-BESS advocacy"**' '**"Ethical fashion advocacy"**'
#  '**"Clean water advocacy"**' '**"Oil industry promotion"**'
#  '**"SAF advocacy push"**' nan '**"Energy cost alarm"**'
#  '**"Green building advocacy"**' '**"Pro-wind energy"**'
#  '**"Sustainable farming progress"**' '**"Pro-forest climate action"**'
#  '**"Climate voter mobilization"**' '**"Clean energy boom"**'
# ...

# %%
key = keys[1]
print(key)
data = df[(df['llm_theme'] == key) & (df['response'] == 'Yes')]
claims = data['claim']
print(claims)
print(claims.iloc[1])
# Out:
# **"Solar energy advocacy"**
# 35     ['Solar energy is a viable option for farmers'...
# 46     ['Solar projects support local schools, commun...
# 79     ['The City of Lebanon, Ohio is partnering with...
# 151    ['One of the most significant benefits of comm...
# Name: claim, dtype: object
# ['Solar projects support local schools, communities, and more', 'Solar energy helps communities invest in a healthy and sustainable future']

# %%
data = df[(df['llm_theme'] == key) & (df['response'] == 'Not related')]
claims = data['claim']
print(claims)
# Out:
# 42                                                    []
# 106    ['Bruce, a Georgia resident, continues to work...
# Name: claim, dtype: object

# %%
path = Path(r"../results/sample_500_bluesky_result_format_result_support_result.csv")
df = pd.read_csv(path)
df.head(5)
# Out:
#    id                                              input  \
# 0  13  ...yes, maybe AI hallucinations, welcomed by (...
# 1  35  That's the point!  You've handed anyone who wa...
# 2  27  This was the plan all along. Remember the atte...
# 3  17  End an 80% done project that will provide jobs...
# 4  22  Great to bring MPs from across parties togethe...
#
#                                         input_prompt     response  \
# 0  Task: Determine whether the claim supports the...          Yes
# 1  Task: Determine whether the claim supports the...          Yes
# 2  Task: Determine whether the claim supports the...  Not related
# 3  Task: Determine whether the claim supports the...  Not related
# 4  Task: Determine whether the claim supports the...          Yes
#
#                                                claim  \
# 0  ["AI hallucinations are being welcomed by auth...
# 1  ['Scientists are willing to lie and obfuscate ...
# 2                   ['This was the plan all along.']
# ...

# %%
keys = df['llm_theme'].unique()

# %%
print(keys)
# Out:
# ['Science under attack' 'Climate rollbacks' 'Climate action collaboration'
#  'End fossil fuels' "Oil's Deceptive Greed" 'Renewable Energy Momentum'
#  'Responsible tourism future' 'Renewable energy surge'
#  'MAGA Climate Deception' 'Deadly Heat Crisis' 'EV transition barriers'
#  'Cleaning fatigue' 'Climate unease' 'Resource expansion drilling'
#  'Fossil fuel deception' 'Greenwashing deception'
#  'Starry night preservation' 'Green Energy Sovereignty'
#  'Insurance Climate Urgency' 'Climate migration crisis'
#  'Water pollution crisis' 'Deforestation & Wildlife Crisis'
#  'Climate justice action' 'Corporate Climate Accountability'
#  "Capitalism's climate doom" 'Climate-fueled wildfires'
#  'Wildlife climate crisis' 'Fossil fuel corruption'
#  'Fascism’s fatal flaws' 'Water resilience' 'Clean Energy Push'
#  'Wealth vs. Welfare' 'Climate Denial Backlash'
#  'Climate injustice exposed' 'Anti-renewable hypocrisy'
#  'Coffee climate crisis' "China's green leap"
# ...

# %%
key = keys[1]
print(key)
data = df[(df['llm_theme'] == key) & (df['response'] == 'Yes')]
claims = data['claim']
print(claims)
print(claims.iloc[1])
# Out:
# Climate rollbacks
# 25     ['The U.S. is abandoning important sectors suc...
# 35     ['Emissions from burning fossil fuels do not c...
# 42     ['Doug Ford government spent $231M to scrap gr...
# 45     ['Congress is about to kill a federal methane ...
# 82     ['Rolling back these protections means more ca...
# 96     ['His platform mirrors the Canadian Associatio...
# 103    ['Any Trump EPA Attempt to Stop Regulating Cli...
# 127    ['The government is blaming farmers for their ...
# 173    ['Trump is eliminating renewable and alternati...
# 182    ['Manufacturing will only come back to this co...
# 214    ['The rollback of environmental protections wi...
# Name: claim, dtype: object
# ['Emissions from burning fossil fuels do not contribute significantly to dangerous pollution, climate change or public health.']

# %%
n = 10
for i in range(n):
    input = inputs[i]
    input_prompt = input_prompts[i]
    response = responses[i]
    print(f"Input: {input}")
    print(f"Input prompt: {input_prompt}\n\n")
    print(f"Output: {response}\n\n")
# Out:
# Input: Claim: Not present
# Ground: Not present
# Warrant: Not present
# Input prompt: """Claim: Not present
# Ground: Not present
# Warrant: Not present"""
#
#  Format the above text in a Python dictionary with values as a list of bullet points.
#
#
#
# Output: {
#     "Claim": [],
#     "Ground": [],
#     "Warrant": []
# }
#
#
# Input: Claim: Not present
# Ground: Not present
# Warrant: Not present
# Input prompt: """Claim: Not present
# Ground: Not present
# Warrant: Not present"""
#
#  Format the above text in a Python dictionary with values as a list of bullet points.
#
#
#
# Output: {
#     "Claim": [],
#     "Ground": [],
#     "Warrant": []
# }
#
#
# Input: Claim: Not present
# Ground: Not present
# Warrant: Not present
# Input prompt: """Claim: Not present
# Ground: Not present
# Warrant: Not present"""
#
#  Format the above text in a Python dictionary with values as a list of bullet points.
#
#
#
# Output: {
#     "Claim": [],
#     "Ground": [],
#     "Warrant": []
# }
#
# ...

# %%
OUTPUT_FILE = Path(f"../results/sample_500_bluesky_result.jsonl")
path = Path(OUTPUT_FILE)
records = []
with open(path, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            records.append(json.loads(line))
        except json.JSONDecodeError:
            print(line)

df = pd.DataFrame(records)

responses = df[1]
metadata = df[2]

# %%
print(metadata[0])
# Out:
# {'cid': 'bafyreid2womneoiv463vkgng3kubgrafnm3szatdpih3ojvzklqcnr65yi',
#  'text': "As if all of his servers don't create enough pollution?",
#  'llm_theme_summ': 'Science under attack',
#  'llm_theme_theme': 'Greenwashing deception',
#  'lda_topic_id': 81,
#  'lda_topic_keywords': 'pollution, air, city, show, focus',
#  'bert_topic_keywords': 'air pollution, air, pollution, exposure, air quality, quality, pm2, airpollution, asthma, mask',
#  'bert_topic_name': '1_air pollution_air_pollution_exposure',
#  'lda_keywords_llm_truth': False,
#  'bert_keywords__llm_truth': False,
#  'llm_theme_llm_truth': False,
#  'llm_summ_llm_truth': False,
#  'lda_keywords_human_truth': 'No',
#  'bert_keywords_human_truth': 'No',
#  'llm_theme_human_truth': 'No',
#  'llm_summ_human_truth': 'No',
#  'Unnamed: 16': None,
#  'Unnamed: 17': None,
#  'Unnamed: 18': None,
#  'Unnamed: 19': None,
#  'row': 2,
# ...

# %%
OUTPUT_FILE = Path(f"../results/sample_500_bluesky_result_format_result.csv")
df = pd.read_csv(OUTPUT_FILE)
df.head(5)
# Out:
#    Unnamed: 0                                              input  \
# 0           0  Can somebody find a way of doing this for him ...
# 1           1  My bears coming over and I'm struggling to fin...
# 2           2  Some Memes, most real guesses. \n\nMy 2025 bin...
# 3           3  And, further, the least sustainable EV on the ...
# 4           4  German-Canadian Raw Materials Alliance Strengt...
#
#                                         input_prompt  \
# 0  """Claim: Not present\nGround: Not present\nWa...
# 1  """Claim: Not present\nGround: "My bears comin...
# 2  """Claim: Not present\nGround: Not present\nWa...
# 3  """Claim: The least sustainable EV (Electric V...
# 4  """Claim: Not present\nGround: German-Canadian...
#
#                                             response  \
# 0  {\n    "Claim": [],\n    "Ground": [],\n    "W...
# 1  {\n    "Claim": ["Not present"],\n    "Ground"...
# 2  {\n    "Claim": [],\n    "Ground": [],\n    "W...
# ...

# %%
OUTPUT_FILE = r'../results/sample_500_meta_result_format_result.jsonl'
path = Path(OUTPUT_FILE)
records = []
with open(path, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            records.append(json.loads(line))
        except json.JSONDecodeError:
            print(line)

df = pd.DataFrame(records)

responses = df[1]
metadata = df[2]

records = []
for i in range(len(df)):
    content = responses[i]['choices'][0]['message']['content']
    
    try:
        dct = json.loads(content)
    except:
        continue
    claim = dct.get("Claim", '')
    if claim is None:
        claim = dct.get('claim', '')
    ground = dct.get('Ground', '')
    warrant = dct.get('Warrant', '')

    md = metadata[i]
    input = md['input']
    input_prompt = md['input_prompt']

    mdmd = md.get('metadata', '')
    mdmd = ast.literal_eval(mdmd)
    llm_theme_human_truth = mdmd.get('llm_theme_human_truth', '')
    llm_theme_llm_truth = mdmd.get('llm_theme_llm_truth', '')
    llm_theme = mdmd.get('llm_theme_theme', '')
    
    row = {'input': input, 'input_prompt': input_prompt, 'response': content, 'claim': claim, 'ground': ground, 'warrant': warrant, 
           'llm_theme_human_truth': llm_theme_human_truth, 
           'llm_theme_llm_truth': llm_theme_llm_truth,
           'llm_theme': llm_theme,
           'metadata': md}
    records.append(row)

out_df = pd.DataFrame(records)
save_dir = path.parent
out_df.to_csv(f"{save_dir}/sample_500_meta_result_format_result.csv")

# %%
OUTPUT_FILE = r'../results/sample_500_meta_result_format_result_result.jsonl'
path = Path(OUTPUT_FILE)
records = []
with open(path, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            records.append(json.loads(line))
        except json.JSONDecodeError:
            print(line)

df = pd.DataFrame(records)

# %%
df[2][3]
# Out:
# {'Unnamed: 0': 7,
#  'input': 'See how YOU can play a part in the next generation of clean energy and explore a career in nuclear energy.  \n\nLearn more about University Of Michigan’s Nuclear Engineering & Radiation Sciences.',
#  'input_prompt': 'Task: Determine whether the claim supports the given theme.\n\nInstructions:\n- Answer "Yes" if the claim supports or promotes the theme.\n- Answer "No" if the claim opposes or argues against the theme.\n- Answer "Not related" if the claim is unrelated to the theme.\n- Base your answer only on the explicit meaning. Do not infer unstated intentions.\n- Output only one of: Yes / No / Not related.\n\nTheme: **"Pro-nuclear advocacy"**\nClaim: [\'You can play a part in the next generation of clean energy\', \'Explore a career in nuclear energy\']\n\nAnswer:\n',
# ...

# %%
path = Path(r"../important_results/sample_500_meta_gpt_direct_results.csv")
df = pd.read_csv(path)

# %%
df.head(10)
# Out:
#       ad_archive_id                                            ad_text  \
# 0   718223234007051  🛑🚨🛑🚨Protecting the Endangerment Finding = Prot...
# 1  1228541608145723  Stop Kamala's Radical Plan for America Before ...
# 2  1499605261479052  Conduct undergraduate research using next-gen ...
# 3   896143312482283  Governor Whitmer: The people working in the Mi...
# 4  1087755083103907  One of the things I love about singing this so...
# 5  1053756599549234  Grateful for federal support in North Carolina...
# 6   586149607698863  Support Sonola Segun’s Recycling Initiative fo...
# 7   621447447265755  Hoosier communities are benefiting from unleas...
# 8   360745056975060  Time & time again we see how most of our elect...
# 9  2817214565122035  “We’re the third fastest warming city in the n...
#
#                                   lda_topic_keywords  \
# 0          american, job, economy, america, michigan
# 1          american, job, economy, america, michigan
# ...

# %%
gpt_raw = df['gpt_raw']
gpt_toulmin_json = df['gpt_toulmin_json']

# %%
len(df)
# Out:
# 500

# %%
ad_texts = df['ad_text']

# %%
ad_texts[0]
# Out:
# 'Yesterday we moved on to the dysgenic portion of the program with Donald Trump and Robert F. Kennedy Jr.’s press conference on autism where the MAGA/MAHA nexus made it clear that they view autistic people as mistakes; unfortunate victims of weak mothers who must be “cured.”'

# %%
print(gpt_raw[10])
# Out:
# {"claim":"A strong majority of Alaskans support using state and federal dollars to develop affordable, local energy.","ground":"Not present","warrant":"Not present"}

# %%
print(gpt_toulmin_json[20])
# Out:
# nan

# %%
path = Path(r"../important_results/sample_500_meta_gpt_results.csv")
df = pd.read_csv(path)

# %%
df.head(10)
# Out:
#       ad_archive_id                                            ad_text  \
# 0   718223234007051  🛑🚨🛑🚨Protecting the Endangerment Finding = Prot...
# 1  1228541608145723  Stop Kamala's Radical Plan for America Before ...
# 2  1499605261479052  Conduct undergraduate research using next-gen ...
# 3   896143312482283  Governor Whitmer: The people working in the Mi...
# 4  1087755083103907  One of the things I love about singing this so...
# 5  1053756599549234  Grateful for federal support in North Carolina...
# 6   586149607698863  Support Sonola Segun’s Recycling Initiative fo...
# 7   621447447265755  Hoosier communities are benefiting from unleas...
# 8   360745056975060  Time & time again we see how most of our elect...
# 9  2817214565122035  “We’re the third fastest warming city in the n...
#
#                                   lda_topic_keywords  \
# 0          american, job, economy, america, michigan
# 1          american, job, economy, america, michigan
# ...

# %%
800*5000
# Out:
# 4000000

# %%
from openai import AsyncOpenAI
client = AsyncOpenAI(api_key="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")

# %%
resp = await client.responses.create(
        model="gpt-5-mini",
        input=[
            {"role": "system", "content": "Hello?"},
            {"role": "user", "content": "what is your name?"},
        ],
        max_output_tokens=256,
    )

# %%
SYSTEM_PROMPT = """You are an information extraction system for Toulmin argument components.

Definitions:
- Claim: a disputable position, judgment, or persuasive statement.
- Ground: evidence or factual support explicitly stated in the text.
- Warrant: a reasoning statement that explicitly explains why the ground supports the claim.

Important rules (read carefully):
- Extract ONLY what is explicitly stated.
- Do NOT infer, assume, or add common-sense reasoning.
- If a component is not explicitly written in the text, output "Not present".
- Warrants are RARE. Most texts do NOT contain an explicit warrant.
- Do NOT create a warrant unless the reasoning is clearly and explicitly stated.
- If the text is purely factual, descriptive, or promotional without a disputable position, the claim is "Not present".
- Return STRICT JSON only:
{"claim": "...", "ground": "...", "warrant": "..."}"""

FEWSHOT_BLOCK = """
Example 1
Text:
Upgrade your Teaching Toolbox! Uncover free interactive tools with standout resources for teaching fiscal policy. Transform your lessons into engaging, unforgettable experiences.

Output:
{"claim":"Free interactive tools can transform fiscal policy lessons into engaging and effective learning experiences.","ground":"Not present","warrant":"Not present"}

Example 2
Text:
Accelerating the future of energy, together

Output:
{"claim":"Not present","ground":"Not present","warrant":"Not present"}

Example 3
Text:
Our spray foam insulation helps reduce energy waste and supports a more sustainable future.

Output:
{"claim":"Using this insulation supports a more sustainable future.","ground":"Our spray foam insulation helps reduce energy waste.","warrant":"Not present"}

Example 4 (explicit warrant case)
Text:
Our insulation reduces energy waste. Because reducing energy waste lowers carbon emissions, it helps protect the environment.

Output:
{"claim":"Using this insulation helps protect the environment.","ground":"Our insulation reduces energy waste.","warrant":"Reducing energy waste lowers carbon emissions."}
""".strip()

# %%
def build_user_prompt(ad_text: str) -> str:
    return f"""{FEWSHOT_BLOCK}

Now analyze the following text.

Text:
{ad_text}

Output:
""".strip()

# %%
model = "gpt-4.1"
ad_text = r"Yesterday we moved on to the dysgenic portion of the program with Donald Trump and Robert F. Kennedy Jr.’s press conference on autism where the MAGA/MAHA nexus made it clear that they view autistic people as mistakes; unfortunate victims of weak mothers who must be “cured.”"
resp = await client.responses.create(
        model=model,
        input=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": build_user_prompt(ad_text)},
        ],
        max_output_tokens=512,
    )

# %%
print(resp.output_text)
# Out:
# {"claim":"The MAGA/MAHA nexus made it clear that they view autistic people as mistakes; unfortunate victims of weak mothers who must be 'cured.'","ground":"Yesterday we moved on to the dysgenic portion of the program with Donald Trump and Robert F. Kennedy Jr.’s press conference on autism.","warrant":"Not present"}

# %%
3000 * 800
# Out:
# 2400000
